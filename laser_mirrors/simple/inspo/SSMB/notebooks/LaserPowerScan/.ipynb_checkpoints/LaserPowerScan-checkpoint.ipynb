# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from epics import PV

# %%
from time import sleep

# %%
SSMBamplavg = PV('SCOPE1ZULP:h1p1:rdAmplAv')
SSMBampldev = PV('SCOPE1ZULP:h1p1:rdAmplDev')
SSMBlaser = PV('SCOPE1ZULP:rdLaserAmpl')
SSMBavglen  = PV('SCOPE1ZULP:rdAvLength')

# %%
current = PV('mlsCurrent:Mnt3collectData.VALD')

# %%
MNFhwp = PV('MNF3C1L2RP')

# %%
hwpdiff = 50
listSSMBavg = []
listSSMBsem = []
listSSMBlaser = []
listhwp = []
listcur = []
try:
    while True:
        hwpold = MNFhwp.get()
        hwpnew = hwpold + hwpdiff
        MNFhwp.put(hwpnew)
        sleep(20)
        print(hwpnew)
        listSSMBavg.append(SSMBamplavg.get())
        listSSMBsem.append(SSMBampldev.get()/SSMBavglen.get()**0.5)
        listSSMBlaser.append(SSMBlaser.get())
        listhwp.append(MNFhwp.get())
        listcur.append(current.get())
except KeyboardInterrupt:
    print('interrupt')
finally:
    resultdf = pd.DataFrame({'motor':listhwp, 'SSMBsignal':listSSMBavg, 'SSMBerror':listSSMBsem, 'SSMBlaser':listSSMBlaser, 'current':listcur})
    print(resultdf)
# Out:
# 500.0
# 550.0
# 600.0
# 650.0
# 700.0
# 750.0
# 800.0
# 850.0
# 900.0
# 950.0
# 1000.0
# 1050.0
# 1100.0
# 1150.0
# 1200.0
# 1250.0
# 1300.0
# 1350.0
# 1400.0
# 1450.0
# 1500.0
# 1550.0
# 1600.0
# 1650.0
# 1700.0
# 1750.0
# 1800.0
# 1850.0
# 1900.0
# 1950.0
# 2000.0
# 2050.0
# 2100.0
# 2150.0
# 2200.0
# 2250.0
# 2300.0
# 2350.0
# 2400.0
# 2450.0
# 2500.0
# 2550.0
# 2600.0
# 2650.0
# 2700.0
# 2750.0
# 2800.0
# 2850.0
# 2900.0
# 2950.0
# 3000.0
# 3050.0
# 3100.0
# 3150.0
# 3200.0
# 3250.0
# 3300.0
# 3350.0
# 3400.0
# 3450.0
# 3500.0
# 3550.0
# 3600.0
# 3650.0
# 3700.0
# 3750.0
# 3800.0
# 3850.0
# 3900.0
# 3950.0
# 4000.0
# 4050.0
# 4100.0
# 4150.0
# 4200.0
# 4250.0
# 4300.0
# 4350.0
# 4400.0
# 4450.0
# 4500.0
# 4550.0
# 4600.0
# 4650.0
# 4700.0
# 4750.0
# 4800.0
# 4850.0
# 4900.0
# 4950.0
# 5000.0
# 5050.0
# 5100.0
# 5150.0
# 5200.0
# 5250.0
# 5300.0
# 5350.0
# 5400.0
# 5450.0
# 5500.0

#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      18         listcur.append(current.get())
#      19 except KeyboardInterrupt:
# ---> 20     print('interrupt')
#      21 finally:
#      22     resultdf = pd.DataFrame({'motor':listhwp, 'SSMBsignal':listSSMBavg, 'SSMBerror':listSSMBsem, 'SSMBlaser':listSSMBlaser, 'current':listcur})
#
# File /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:694, in OutStream.write(self, string)
#     692     self.pub_thread.schedule(self._flush)
#     693 else:
# --> 694     self._schedule_flush()
#     696 return len(string)
#
# File /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:590, in OutStream._schedule_flush(self)
#     587 def _schedule_in_thread():
#     588     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 590 self.pub_thread.schedule(_schedule_in_thread)
#
# File /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py:701, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     694         data = zmq.Frame(
#     695             data,
#     696             track=track,
#     697             copy=copy or None,
#     698             copy_threshold=self.copy_threshold,
#     699         )
#     700     data.group = group
# --> 701 return super().send(data, flags=flags, copy=copy, track=track)
#
# File _zmq.py:1073, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1121, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1320, in zmq.backend.cython._zmq._send_copy()
#
# File _zmq.py:141, in zmq.backend.cython._zmq._check_rc()
#
# KeyboardInterrupt:

# %%
resultdf.to_hdf('SSMB_LaserPowerScan_20250306.hdf5', key='data')
# Out:
# /tmp/ipykernel_21117/3351920631.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block1_values] [items->Index(['SSMBlaser'], dtype='object')]
#
#   resultdf.to_hdf('SSMB_LaserPowerScan_20250306.hdf5', key='data')

# %%
resultdf.plot(x='motor', y='SSMBsignal', kind='scatter')
# Out:
# <AxesSubplot:xlabel='motor', ylabel='SSMBsignal'>

# %%
def powersin(s):
    return np.sin(np.pi*(s-6250)/5500 )**2

# %%
xr = np.linspace(0,12000,1000)

plt.errorbar(resultdf['motor'], resultdf['SSMBsignal']*1000, resultdf['SSMBerror']*1000, ls='none', marker='o', capsize=2)
plt.plot(xr, powersin(xr)*3500)
# plt.xlim(5500,7000)
# plt.ylim(0,500)
plt.xlabel('half wave plate motor steps')
plt.ylabel('coherent radiation signal / mV')
# Out:
# Text(0, 0.5, 'coherent radiation signal / mV')

# %%
xr = np.linspace(5500,7000,200)

plt.errorbar(resultdf['motor'], resultdf['SSMBsignal']*1000, resultdf['SSMBerror']*1000, ls='none', marker='o', capsize=2)
plt.plot(xr, powersin(xr)*3500)
plt.xlim(5500,7000)
plt.ylim(0,500)
plt.xlabel('half wave plate motor steps')
plt.ylabel('coherent radiation signal / mV')
# Out:
# Text(0, 0.5, 'coherent radiation signal / mV')

# %%
plt.errorbar(resultdf['motor'], resultdf['SSMBsignal']*1000, resultdf['SSMBerror']*1000, ls='none', marker='o', capsize=2)
plt.xlim(11000,12000)
plt.ylim(0,300)
plt.xlabel('half wave plate motor steps')
plt.ylabel('coherent radiation signal / mV')
# Out:
# Text(0, 0.5, 'coherent radiation signal / mV')

# %%
SSMBlaser.get()
# Out:
# nan
