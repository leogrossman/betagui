# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
from time import sleep

# %%
import epics

# %%
AK10=epics.PV('AKC10VP')

# %%
AK11=epics.PV('AKC11VP')

# %%
AK10.get()
# Out:
# 0.0

# %%
def AK10cbf(list10=None, list11=None, value=None, timestamp=None, **kwargs):
    if value == 0:
        list11.append(AK11.get())
    else:
        list10.append(value)

# %%
AK10list = []
AK11list = []
AK10cb = AK10.add_callback(AK10cbf, list10=AK10list, list11=AK11list)
sleep(60)
AK10.remove_callback(AK10cb)

# %%
print(AK10list)
print(AK11list)
# Out:
# [3.0, 4.0, 5.0, 5.1, 5.0, 1.0]
# [3.14, 0.0, 0.0, 0.0, 1.0]
