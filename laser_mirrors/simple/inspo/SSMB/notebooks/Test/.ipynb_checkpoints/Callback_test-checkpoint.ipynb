# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
import epics

# %%
AK10=epics.PV('AKC10VP')

# %%
AK10.get()
# Out:
# 0.0

# %%
def AK10cbf(value=None, timestamp=None, **kwargs):
    print(value)
    print(timestamp)

# %%
AK10cb = AK10.add_callback(AK10cbf)
# Out:
# 1.0
# 1721030261.675999
# 2.0
# 1721030266.889777
# 0.0
# 1721030281.242071

# %%
AK10.remove_callback(AK10cb)

# %%
testn = 0

# %%
def inctestn():
    global testn
    testn += 1

# %%
inctestn()
