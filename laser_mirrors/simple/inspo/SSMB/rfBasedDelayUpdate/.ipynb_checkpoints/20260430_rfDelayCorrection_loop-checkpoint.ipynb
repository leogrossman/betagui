# %%
from epics import PV
freqPV = PV('MCLKHGP:rdFrq')
dlyGenPV = PV('SSMBCCZULP:cell1OnDly')

# %%
from time import sleep

# %%
loopactivepv = PV('AKC15VP')
addelaypv = PV('AKC16VP')

# %%
dg535Delay = 800450 #us
pcDelay = -6.00 #us
currentRF = freqPV.get()
oldDelay = dlyGenPV.get()
print('old Delay:', oldDelay, 'us')

targetDelay = (500000/currentRF * 800000) - dg535Delay + pcDelay
print('new Delay:', targetDelay, 'us')
# Out:
# old Delay: 46.08036 us
# new Delay: 2.3268434213241562 us

# %%
dlyGenPV.put(targetDelay)
# Out:
# 1

# %%
dg535Delay = 800450 #us
heartbeat = ['/', '-', '\\', '|']
try:
    loopactivepv.put(1)
    i = 0
    while True:
        if loopactivepv.get():
            targetDelay = (500000/freqPV.get() * 800000) - dg535Delay + addelaypv.get()
            print('\r', heartbeat[i%len(heartbeat)], 'new Delay:', targetDelay, 'us', end='')
            dlyGenPV.put(targetDelay)
        sleep(0.5)
        i += 1
finally:
    loopactivepv.put(0)
# Out:
#  - new Delay: 2.3268434213241562 us
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 10
#       9     dlyGenPV.put(targetDelay)
# ---> 10 sleep(0.5)
#      11 i += 1
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 13
#      11         i += 1
#      12 finally:
# ---> 13     loopactivepv.put(0)
#
# File /usr/local/lib/python3.10/site-packages/epics/pv.py:41, in _ensure_context.<locals>.wrapped(self, *args, **kwargs)
#      39     raise RuntimeError('Expected CA context is unset')
#      40 if expected_context == initial_context:
# ---> 41     return func(self, *args, **kwargs)
#      43 # If not using the expected context, switch to it here:
#      44 if initial_context is not None:
#
# File /usr/local/lib/python3.10/site-packages/epics/pv.py:673, in PV.put(self, value, wait, timeout, use_complete, callback, callback_data)
#     667         callback(pvname=pvname, **kws)
#     669 self._put_complete = (False
#     670                       if use_complete
#     671                       else None)
# --> 673 return ca.put(self.chid, value,
#     674               wait=wait, timeout=timeout,
#     675               callback=_put_callback if use_complete or callback else None,
#     676               callback_data=callback_data)
#
# File /usr/local/lib/python3.10/site-packages/epics/ca.py:656, in withConnectedCHID.<locals>.wrapper(*args, **kwds)
#     652             fmt ="%s() timed out waiting '%s' to connect (%d seconds)"
#     653             raise ChannelAccessException(fmt % (fcn.__name__,
#     654                                         name(chid), timeout))
# --> 656 return fcn(*args, **kwds)
#
# File /usr/local/lib/python3.10/site-packages/epics/ca.py:1659, in put(chid, value, wait, timeout, callback, callback_data, ftype)
#    1656         pass
#    1657     return val
# -> 1659 @withConnectedCHID
#    1660 def put(chid, value, wait=False, timeout=30, callback=None,
#    1661         callback_data=None, ftype=None):
#    1662     """sets the Channel to a value, with options to either wait
#    1663     (block) for the processing to complete, or to execute a
#    1664     supplied callback function when the process has completed.
#    (...)
#    1694
#    1695     """
#    1696     if ftype is None:
#
# KeyboardInterrupt:

# %%
if loopactivepv.get():
    print('yes')
